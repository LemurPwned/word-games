# %%
# !git clone git://github.com/LemurPwned/word-games.git
# !cd word-games & pip install -e .
# !pip3 install matplotlib ipywidgets rich

# %%
import word_games.orlovski.diode as de

dg = de.DiodeGameEngine()
box = dg.ipythonwidgets_visual()
box

# %%
import word_games.orlovski.rules as ru

dg = ru.RuleGameEngine()
box = dg.ipythonwidgets_visual()
box

# %%
# %matplotlib widget

from word_games.orlovski.calibrate import x3DCalibrateEngine
engine = x3DCalibrateEngine(30, 1)    
engine()
# Out:
# Generating seed for grid size: 30
# Step size: 1
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
